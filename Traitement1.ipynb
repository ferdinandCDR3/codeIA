# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv(r"C:\Users\ferdinand\Documents\dataset\Classification\personalKeyIndicatorOfHeartDisease\heart_2020_cleaned.csv")
#convert the dataset into a Pandas dataframe and add the target column named 'Price'
## df = pd.DataFrame(data.data, columns=data.feature_names)
# df['Price'] = data.target
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
#vérifier les valeurs nulles
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
#compress the columns 'DIS', 'RAD', 'INDUS' into 1 column
pca = PCA(n_components=1)
#call the compressed column 'new'
df['new'] = pca.fit_transform(df[['colname1', 'colname2', 'colname3']])
#drop the three columns from the dataset
df = df.drop(['colname1', 'colname2', 'colname3'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ferdinand\Documents\codeIA\Traitement1.ipynb Cell 5' in <cell line: 14>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ferdinand/Documents/codeIA/Traitement1.ipynb#ch0000004?line=10'>11</a>     return vif_table
#      <a href='vscode-notebook-cell:/c%3A/Users/ferdinand/Documents/codeIA/Traitement1.ipynb#ch0000004?line=12'>13</a> #print the VIF table for each variable
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ferdinand/Documents/codeIA/Traitement1.ipynb#ch0000004?line=13'>14</a> print(create_vif(df))
#
# c:\Users\ferdinand\Documents\codeIA\Traitement1.ipynb Cell 5' in create_vif(dataframe)
#       <a href='vscode-notebook-cell:/c%3A/Users/ferdinand/Documents/codeIA/Traitement1.ipynb#ch0000004?line=6'>7</a> vif_table['variables'] = dataframe.columns
# ...
